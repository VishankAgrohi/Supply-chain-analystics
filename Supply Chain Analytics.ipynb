# %% [markdown]
# # **Project Name**    - Supply Chain Analytics

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Vishank Agrohi

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Project Summary: SCMS Delivery Insights – A Data-Driven Approach to Supply Chain Optimization
# This project focuses on analyzing the SCMS (Supply Chain Management System) Delivery History dataset to uncover meaningful insights and optimize logistics operations through data visualization and analytics. Using Python and powerful libraries like Pandas, Matplotlib, and Seaborn, we generated multiple visualizations to understand trends in delivery performance, freight costs, product movement, and geographical distribution.
#
# 🔍 Key Objectives:
# Understand delivery patterns and shipping costs across countries.
#
# Identify top-performing products and regions.
#
# Detect inefficiencies in the supply chain.
#
# Suggest actionable improvements for business growth.
#
# 📊 Key Techniques:
# Bar charts, pie charts, line plots, heatmaps, and distribution plots.
#
# Grouping, aggregation, and correlation analysis.
#
# Exploratory Data Analysis (EDA) and visual storytelling.
#
# 🧠 Key Insights:
# A small number of countries and products contribute significantly to total revenue.
#
# Certain routes and INCOTERMS lead to high freight costs, suggesting optimization opportunities.
#
# Some product lines or regions show negative growth, requiring strategic review.
#
# Vendor and delivery time performance can be improved for better service levels.
#
# 💼 Business Impact:
# The visual insights derived from this analysis help stakeholders:
#
# Reduce logistics and freight costs.
#
# Prioritize profitable regions and products.
#
# Streamline vendor and supplier performance.
#
# Improve inventory planning and demand forecasting.
#
# Mitigate risks from underperforming areas.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In large-scale supply chain operations, inefficient delivery management, high freight costs, and lack of visibility into vendor and product performance can lead to significant financial losses and poor customer service. The organization currently lacks a data-driven approach to evaluate its delivery history, identify inefficiencies, and make informed decisions.
#
# This project aims to analyze the SCMS Delivery History dataset to:
#
# Detect patterns in delivery timelines and cost fluctuations.
#
# Identify top-performing and underperforming countries, vendors, and product lines.
#
# Visualize trends to support better inventory, logistics, and procurement strategies.
#
# By uncovering hidden insights through data visualization and analytics, the goal is to optimize supply chain operations, reduce unnecessary costs, and enhance overall business efficiency.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# *Answer* The primary business objective of this project is to optimize supply chain efficiency by leveraging historical delivery data to drive informed decision-making. Through exploratory data analysis and visualization of the SCMS Delivery History dataset, the goal is to:
#
# Minimize freight and logistics costs by identifying expensive delivery routes and patterns.
#
# Maximize profitability by focusing on high-performing products, vendors, and delivery destinations.
#
# Improve operational efficiency by detecting and addressing bottlenecks in the delivery process.
#
# Enhance supply chain transparency by providing actionable insights to stakeholders for strategic planning.
#
# Reduce risk by identifying underperforming regions or vendors contributing to delays or losses.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
read_file = pd.read_csv('/content/SCMS_Delivery_History_Dataset.csv')
df = pd.DataFrame(read_file)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 0   1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire
# 1   3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2   4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire
# 3  15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4  16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
#
#   Managed By  Fulfill Via Vendor INCO Term Shipment Mode  ...  \
# 0   PMO - US  Direct Drop              EXW           Air  ...
# 1   PMO - US  Direct Drop              EXW           Air  ...
# 2   PMO - US  Direct Drop              FCA           Air  ...
# 3   PMO - US  Direct Drop              EXW           Air  ...
# 4   PMO - US  Direct Drop              EXW           Air  ...
#
#   Unit of Measure (Per Pack) Line Item Quantity Line Item Value Pack Price  \
# 0                         30                 19           551.0      29.00
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (10324, 33)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
#  11  PO Sent to Vendor Date        10324 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# ID                                 0
# Project Code                       0
# PQ #                               0
# PO / SO #                          0
# ASN/DN #                           0
# Country                            0
# Managed By                         0
# Fulfill Via                        0
# Vendor INCO Term                   0
# Shipment Mode                    360
# PQ First Sent to Client Date       0
# PO Sent to Vendor Date             0
# Scheduled Delivery Date            0
# Delivered to Client Date           0
# Delivery Recorded Date             0
# Product Group                      0
# Sub Classification                 0
# Vendor                             0
# Item Description                   0
# Molecule/Test Type                 0
# Brand                              0
# Dosage                          1736
# Dosage Form                        0
# Unit of Measure (Per Pack)         0
# Line Item Quantity                 0
# ...

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['ID', 'Project Code', 'PQ #', 'PO / SO #', 'ASN/DN #', 'Country',
#        'Managed By', 'Fulfill Via', 'Vendor INCO Term', 'Shipment Mode',
#        'PQ First Sent to Client Date', 'PO Sent to Vendor Date',
#        'Scheduled Delivery Date', 'Delivered to Client Date',
#        'Delivery Recorded Date', 'Product Group', 'Sub Classification',
#        'Vendor', 'Item Description', 'Molecule/Test Type', 'Brand', 'Dosage',
#        'Dosage Form', 'Unit of Measure (Per Pack)', 'Line Item Quantity',
#        'Line Item Value', 'Pack Price', 'Unit Price', 'Manufacturing Site',
#        'First Line Designation', 'Weight (Kilograms)', 'Freight Cost (USD)',
#        'Line Item Insurance (USD)'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#                  ID  Unit of Measure (Per Pack)  Line Item Quantity  \
# count  10324.000000                10324.000000        10324.000000
# mean   51098.968229                   77.990895        18332.534870
# std    31944.332496                   76.579764        40035.302961
# min        1.000000                    1.000000            1.000000
# 25%    12795.750000                   30.000000          408.000000
# 50%    57540.500000                   60.000000         3000.000000
# 75%    83648.250000                   90.000000        17039.750000
# max    86823.000000                 1000.000000       619999.000000
#
#        Line Item Value    Pack Price    Unit Price  Line Item Insurance (USD)
# count     1.032400e+04  10324.000000  10324.000000               10037.000000
# mean      1.576506e+05     21.910241      0.611701                 240.117626
# std       3.452921e+05     45.609223      3.275808                 500.190568
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# ID                              10324
# Project Code                      142
# PQ #                             1237
# PO / SO #                        6233
# ASN/DN #                         7030
# Country                            43
# Managed By                          4
# Fulfill Via                         2
# Vendor INCO Term                    8
# Shipment Mode                       4
# PQ First Sent to Client Date      765
# PO Sent to Vendor Date            897
# Scheduled Delivery Date          2006
# Delivered to Client Date         2093
# Delivery Recorded Date           2042
# Product Group                       5
# Sub Classification                  6
# Vendor                             73
# Item Description                  184
# Molecule/Test Type                 86
# Brand                              48
# Dosage                             54
# Dosage Form                        17
# Unit of Measure (Per Pack)         31
# Line Item Quantity               5065
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Data Wrangling Code

import pandas as pd
import numpy as np

# Step 1: Load the dataset
file_path = '/content/SCMS_Delivery_History_Dataset.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)# Step 2: Inspect the dataset
print("Shape of dataset:", df.shape)
print("\nDataset Info:")
print(df.info())
print("\nFirst 5 rows:")
print(df.head())

# Step 3: Handle missing values
# Option 1: Drop rows with missing values
# df = df.dropna()

# Option 2: Fill missing values with mean/median/mode
for column in df.select_dtypes(include=[np.number]).columns:
    df[column].fillna(df[column].mean(), inplace=True)

# Step 4: Handle duplicates
df = df.drop_duplicates()

# Step 5: Rename columns (if necessary)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Step 6: Convert data types (if necessary)
# Example: df['date'] = pd.to_datetime(df['date'])

# Step 7: Feature engineering (if applicable)
# Example: Create a new column based on existing ones
# df['new_feature'] = df['feature1'] / df['feature2']

# Step 8: Encode categorical variables
df = pd.get_dummies(df, drop_first=True)

# Final check
print("\nCleaned dataset shape:", df.shape)
print(df.head())
# Out:
# Shape of dataset: (10324, 33)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10324 entries, 0 to 10323
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            10324 non-null  int64
#  1   Project Code                  10324 non-null  object
#  2   PQ #                          10324 non-null  object
#  3   PO / SO #                     10324 non-null  object
#  4   ASN/DN #                      10324 non-null  object
#  5   Country                       10324 non-null  object
#  6   Managed By                    10324 non-null  object
#  7   Fulfill Via                   10324 non-null  object
#  8   Vendor INCO Term              10324 non-null  object
#  9   Shipment Mode                 9964 non-null   object
#  10  PQ First Sent to Client Date  10324 non-null  object
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("SCMS_Delivery_History_Dataset.csv")

# Convert date columns to datetime
date_cols = ['Delivered to Client Date']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# Clean numeric columns (remove commas, convert to float)
df['Freight Cost (USD)'] = pd.to_numeric(df['Freight Cost (USD)'].astype(str).str.replace(",", ""), errors='coerce')
df['Weight (Kilograms)'] = pd.to_numeric(df['Weight (Kilograms)'].astype(str).str.replace(",", ""), errors='coerce')
df['Line Item Value'] = pd.to_numeric(df['Line Item Value'], errors='coerce')
df['Line Item Quantity'] = pd.to_numeric(df['Line Item Quantity'], errors='coerce')

# Optional: Drop rows with missing key values for plotting
df.dropna(subset=["Line Item Value", "Delivered to Client Date"], inplace=True)

# Set style
sns.set(style="whitegrid")

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
top_countries = df.groupby("Country")["Line Item Value"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette="viridis")
plt.title("Top 10 Countries by Total Line Item Value")
plt.xlabel("Total Line Item Value (USD)")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Bar chart suits ranking by value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Reveals which countries contribute most to revenue

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Helps in allocating resources and strengthening partnerships.
#
# ❗ Overreliance on few countries could risk business stability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
shipment_mode_counts = df["Shipment Mode"].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=shipment_mode_counts.values, y=shipment_mode_counts.index, palette="Set2")
plt.title("Distribution of Shipment Modes")
plt.xlabel("Number of Deliveries")
plt.ylabel("Shipment Mode")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Bar chart makes categorical comparison easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Shows air is heavily used — high cost.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Can cut costs by switching to sea/truck where possible.
#
# ❗ Heavy reliance on air freight may reduce profit margins.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
monthly_trends = df.set_index("Delivered to Client Date").resample("M")["Line Item Value"].sum()

plt.figure(figsize=(14, 6))
monthly_trends.plot(marker='o', color="steelblue")
plt.title("Monthly Delivery Value Trend")
plt.xlabel("Month")
plt.ylabel("Total Line Item Value (USD)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Line chart captures time trends well.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Spikes may align with budget cycles or emergencies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Helps plan inventory and vendor coordination.
#
# ❗ Dips may signal delivery issues or delays.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
top_vendors = df.groupby("Vendor")["Line Item Value"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_vendors.values, y=top_vendors.index, palette="coolwarm")
plt.title("Top 10 Vendors by Total Line Item Value")
plt.xlabel("Total Line Item Value (USD)")
plt.ylabel("Vendor")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Focuses on supplier contribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Top few vendors dominate total value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Enables better vendor relationship management.
#
# ❗ Too much dependency on a few vendors is risky.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
product_value = df.groupby("Product Group")["Line Item Value"].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=product_value.values, y=product_value.index, palette="crest")
plt.title("Product Group vs. Line Item Value")
plt.xlabel("Total Line Item Value")
plt.ylabel("Product Group")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Highlights which product types generate revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Some product groups may be undervalued.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Allows prioritizing high-margin categories.
#
# ❗ Low-performing groups may need optimization or phase-out.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Line Item Quantity", y="Line Item Value", alpha=0.6)
plt.title("Line Item Quantity vs. Line Item Value")
plt.xlabel("Quantity")
plt.ylabel("Value (USD)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Reveals quantity vs. value correlation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer High-value items may not need bulk shipping.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Helps optimize pricing strategy.
#
# ❗ Bulk low-value items can waste inventory space.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
fulfill_value = df.groupby("Fulfill Via")["Line Item Value"].sum()

plt.figure(figsize=(8, 6))
fulfill_value.plot.pie(autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"))
plt.title("Fulfillment Method by Value")
plt.ylabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Pie chart shows proportions clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Drop shipments dominate

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Could explore decentralizing operations.
#
# ❗ Too much reliance on one method may hurt agility.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Freight Cost (USD)", y="Line Item Value", alpha=0.5)
plt.title("Freight Cost vs. Line Item Value")
plt.xlabel("Freight Cost (USD)")
plt.ylabel("Line Item Value (USD)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Analyze logistics efficiency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Some deliveries cost too much for low value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Optimize shipping routes and package sizes.
#
# ❗ High freight costs may erode profit.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Weight (Kilograms)", y="Line Item Value", alpha=0.5)
plt.title("Weight vs. Line Item Value")
plt.xlabel("Weight (Kg)")
plt.ylabel("Line Item Value (USD)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Understand shipping cost vs. value.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Light items may have high value → cost-efficient.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Shift to smaller high-value products where possible.
#
# ❗ Heavy low-value items hurt cost-effectiveness.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
top_brands = df.groupby("Brand")["Line Item Value"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x=top_brands.values, y=top_brands.index, palette="magma")
plt.title("Top 10 Brands by Total Line Item Value")
plt.xlabel("Total Line Item Value (USD)")
plt.ylabel("Brand")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Identifies top-performing brands.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Useful for promotional or partnership focus.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Encourage bulk deals with leading brands.
#
# ❗ Low-performing brands may need phase-out or renegotiation.

# %% [markdown]
# #### Chart - 11- Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Select only relevant numeric columns
numeric_cols = ['Line Item Quantity', 'Line Item Value', 'Pack Price', 'Unit Price',
                'Weight (Kilograms)', 'Freight Cost (USD)', 'Line Item Insurance (USD)']

# Convert Line Item Insurance column to numeric (if needed)
df['Line Item Insurance (USD)'] = pd.to_numeric(df['Line Item Insurance (USD)'].astype(str).str.replace(",", ""), errors='coerce')

# Compute correlation matrix
corr_matrix = df[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Key Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer To understand how different numerical features relate to each other — e.g., does increasing weight increase cost?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Unit Price, Pack Price, and Line Item Value show strong positive correlation.
#
# Freight Cost has moderate correlation with Weight and Line Item Value, implying heavier and more valuable shipments cost more to move.

# %% [markdown]
# #### Chart - 12 - Pair Plot

# %%
# Pair Plot visualization code
# Filter the same numeric columns for pair plot
pairplot_df = df[numeric_cols].dropna()

# Pair plot
sns.pairplot(pairplot_df, diag_kind='kde', corner=True, plot_kws={'alpha': 0.5})
plt.suptitle("Pair Plot of Key Shipment Features", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer To visually analyze distributions and pairwise relationships (e.g., clusters, outliers, linear trends) among critical cost/quantity features.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Line Item Value increases with both Unit Price and Quantity.
#
# Freight Cost appears more dispersed, with some outliers at low value but high cost (loss-makers).
#
# Linear relationships visible between pricing metrics (Pack Price, Unit Price).

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer
# ✅ 1. Optimize Freight and Logistics Costs
# Insight: Certain months or regions show unusually high freight costs.
#
# Action:
#
# Use predictive models to anticipate shipping spikes.
#
# Negotiate better rates or use alternative modes of transport for costly routes.
#
# Impact: Reduces overall logistics expenditure and improves profit margins.
#
# ✅ 2. Focus on High-Performing Countries and Products
# Insight: A small set of countries/products contribute most of the revenue.
#
# Action:
#
# Prioritize supply and marketing efforts in those regions.
#
# Streamline products with high value-to-weight ratio.
#
# Impact: Drives revenue growth with efficient resource allocation.
#
# ✅ 3. Improve Vendor and Supplier Management
# Insight: Heavy reliance on a few INCO terms or vendors.
#
# Action:
#
# Diversify vendor base to avoid supply disruption.
#
# Audit supplier performance (on-time delivery, cost, volume).
#
# Impact: Minimizes risks and creates leverage in negotiations.
#
# ✅ 4. Enhance Demand Forecasting and Inventory Planning
# Insight: Line item quantity distribution shows erratic demand patterns.
#
# Action:
#
# Implement demand forecasting models.
#
# Adjust inventory buffer levels to avoid over/understocking.
#
# Impact: Improves service levels and reduces holding costs.
#
# ✅ 5. Address Areas of Negative Growth
# Insight: Some product groups or countries have declining performance.
#
# Action:
#
# Investigate causes: market saturation, poor distribution, etc.
#
# Reassess market potential or exit unprofitable segments.
#
# Impact: Prevents loss-making operations and reallocates efforts wisely

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of the SCMS Delivery History dataset reveals valuable insights that can significantly influence strategic business decisions. By leveraging data visualization and key performance metrics, the organization can:
#
# Reduce logistics and freight costs by identifying and optimizing high-cost shipping routes.
#
# Increase revenue by focusing efforts on high-performing countries and products.
#
# Enhance supplier and vendor performance through careful evaluation and diversification.
#
# Improve demand forecasting and inventory management to meet customer needs efficiently.
#
# Identify and mitigate areas of negative growth, ensuring resources are allocated to the most profitable and impactful regions or product lines.
#
# Overall, these insights support a data-driven approach to supply chain optimization, enabling the business to operate more efficiently, improve service levels, and sustain long-term growth. Embracing these strategies will lead to a more agile, resilient, and customer-focused supply chain operation.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
